# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("../Datasets/SuperStore.csv")

print(df.shape)
df.head()
# Out:
# (9993, 25)
#    Unnamed: 0        Order ID  Order Date   Ship Date       Ship Mode  \
# 0           0  CA-2016-152156  2016-11-08  2016-11-11    Second Class
# 1           1  CA-2016-152156  2016-11-08  2016-11-11    Second Class
# 2           2  CA-2016-138688  2016-06-12  2016-06-16    Second Class
# 3           3  US-2015-108966  2015-10-11  2015-10-18  Standard Class
# 4           4  US-2015-108966  2015-10-11  2015-10-18  Standard Class
#
#   Customer ID    Customer Name    Segment             City       State  ...  \
# 0    CG-12520      Claire Gute   Consumer        Henderson    Kentucky  ...
# 1    CG-12520      Claire Gute   Consumer        Henderson    Kentucky  ...
# 2    DV-13045  Darrin Van Huff  Corporate      Los Angeles  California  ...
# 3    SO-20335   Sean O'Donnell   Consumer  Fort Lauderdale     Florida  ...
# 4    SO-20335   Sean O'Donnell   Consumer  Fort Lauderdale     Florida  ...
#
#                                         Product Name     Sales Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600        2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400        3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200        2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775        5
# 4                     Eldon Fold 'N Roll Cart System   22.3680        2
#
#   Discount    Profit Ship Month  Ship Year  Order Month  Order Year  \
# 0     0.00   41.9136         11       2016           11        2016
# 1     0.00  219.5820         11       2016           11        2016
# 2     0.00    6.8714          6       2016            6        2016
# 3     0.45 -383.0310         10       2015           10        2015
# 4     0.20    2.5164         10       2015           10        2015
#
#    Order Delay
# 0       3 days
# 1       3 days
# 2       4 days
# 3       7 days
# 4       7 days
#
# [5 rows x 25 columns]

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9993 entries, 0 to 9992
# Data columns (total 25 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     9993 non-null   int64
#  1   Order ID       9993 non-null   object
#  2   Order Date     9993 non-null   object
#  3   Ship Date      9993 non-null   object
#  4   Ship Mode      9993 non-null   object
#  5   Customer ID    9993 non-null   object
#  6   Customer Name  9993 non-null   object
#  7   Segment        9993 non-null   object
#  8   City           9993 non-null   object
#  9   State          9993 non-null   object
#  10  Postal Code    9993 non-null   int64
#  11  Region         9993 non-null   object
#  12  Product ID     9993 non-null   object
#  13  Category       9993 non-null   object
#  14  Sub-Category   9993 non-null   object
#  15  Product Name   9993 non-null   object
#  16  Sales          9993 non-null   float64
#  17  Quantity       9993 non-null   int64
#  18  Discount       9993 non-null   float64
#  19  Profit         9993 non-null   float64
#  20  Ship Month     9993 non-null   int64
#  21  Ship Year      9993 non-null   int64
#  22  Order Month    9993 non-null   int64
#  23  Order Year     9993 non-null   int64
#  24  Order Delay    9993 non-null   object
# dtypes: float64(3), int64(7), object(15)
# memory usage: 1.9+ MB
# None

# %%
print(df.isnull().sum())
# Out:
# Unnamed: 0       0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# Ship Month       0
# Ship Year        0
# Order Month      0
# Order Year       0
# Order Delay      0
# dtype: int64

# %%
df.describe()
# Out:
#         Unnamed: 0   Postal Code         Sales     Quantity     Discount  \
# count  9993.000000   9993.000000   9993.000000  9993.000000  9993.000000
# mean   4996.659161  55191.576403    229.852846     3.789753     0.156188
# std    2885.264122  32065.074478    623.276074     2.225149     0.206457
# min       0.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2498.000000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.000000  56560.000000     54.480000     3.000000     0.200000
# 75%    7495.000000  90008.000000    209.940000     5.000000     0.200000
# max    9993.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit   Ship Month    Ship Year  Order Month   Order Year
# count  9993.000000  9993.000000  9993.000000  9993.000000  9993.000000
# mean     28.660971     7.743520  2015.737616     7.810067  2015.722406
# std     234.271476     3.340433     1.126063     3.284598     1.123479
# min   -6599.978000     1.000000  2014.000000     1.000000  2014.000000
# 25%       1.731000     5.000000  2015.000000     5.000000  2015.000000
# 50%       8.671000     9.000000  2016.000000     9.000000  2016.000000
# 75%      29.364000    11.000000  2017.000000    11.000000  2017.000000
# max    8399.976000    12.000000  2018.000000    12.000000  2017.000000

# %%
print("Total Sales:", df["Sales"].sum())
print("Total Profit:", df["Profit"].sum())
# Out:
# Total Sales: 2296919.4883000003
# Total Profit: 286409.0805

# %%
sales_category = df.groupby("Category")["Sales"].sum()

print(sales_category)

sales_category.plot(
    kind="bar",
    figsize=(8,5)
)

plt.title("Sales by Category")
plt.show()
# Out:
# Category
# Furniture          741718.4233
# Office Supplies    719047.0320
# Technology         836154.0330
# Name: Sales, dtype: float64

# %%
profit_category = df.groupby("Category")["Profit"].sum()

profit_category.plot(
    kind="bar",
    figsize=(8,5)
)

plt.title("Profit by Category")
plt.show()

# %%
top_states = df.groupby("State")["Sales"].sum().sort_values(
    ascending=False
).head(10)

top_states.plot(
    kind="bar",
    figsize=(10,5)
)

plt.title("Top 10 States by Sales")
plt.show()

# %%
region_sales = df.groupby("Region")["Sales"].sum()

region_sales.plot(
    kind="pie",
    autopct="%1.1f%%",
    figsize=(7,7)
)

plt.title("Sales Distribution by Region")
plt.show()

# %%
monthly_sales = df.groupby("Order Month")["Sales"].sum()

monthly_sales.plot(
    kind="line",
    figsize=(10,5)
)

plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.show()

# %%
top_products = df.groupby("Product Name")["Sales"].sum().sort_values(
    ascending=False
).head(10)

print(top_products)
# Out:
# Product Name
# Canon imageCLASS 2200 Advanced Copier                                          61599.824
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind    27453.384
# Cisco TelePresence System EX90 Videoconferencing Unit                          22638.480
# HON 5400 Series Task Chairs for Big and Tall                                   21870.576
# GBC DocuBind TL300 Electric Binding System                                     19823.479
# GBC Ibimaster 500 Manual ProClick Binding System                               19024.500
# Hewlett Packard LaserJet 3310 Copier                                           18839.686
# HP Designjet T520 Inkjet Large Format Printer - 24" Color                      18374.895
# GBC DocuBind P400 Electric Binding System                                      17965.068
# High Speed Automatic Electric Letter Opener                                    17030.312
# Name: Sales, dtype: float64

# %%
print("Total Sales:", df["Sales"].sum())
print("Total Profit:", df["Profit"].sum())
# Out:
# Total Sales: 2296919.4883000003
# Total Profit: 286409.0805

# %%
sales_category = df.groupby("Category")["Sales"].sum()
print(sales_category)
# Out:
# Category
# Furniture          741718.4233
# Office Supplies    719047.0320
# Technology         836154.0330
# Name: Sales, dtype: float64
